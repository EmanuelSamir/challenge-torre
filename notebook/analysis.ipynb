# %%
import pandas as pd
import numpy as np

# %%
filename = '../data/reed_uk.csv'
dtypes = {'category': str, 
          'city': str,
          'company_name': str,
          'geo': str,
          'job_board': str,
          'job_description': str, 
          'job_requirements': str, 
          'job_title': str, 
          'job_type': str,
          'post_date': str,
          'salary_offered': str,
          'state': str
         }
df = pd.read_csv(filename, dtype = dtypes, )

# %%
print(df.columns)
print(100*'-')
print(df.isnull().any())
print(100*'-')
print(df.head())
# Out:
# Index(['category', 'city', 'company_name', 'geo', 'job_board',
#        'job_description', 'job_requirements', 'job_title', 'job_type',
#        'post_date', 'salary_offered', 'state'],
#       dtype='object')
# ----------------------------------------------------------------------------------------------------
# category            False
# city                False
# company_name        False
# geo                 False
# job_board           False
# job_description     False
# job_requirements     True
# job_title           False
# job_type            False
# post_date           False
# salary_offered      False
# state                True
# dtype: bool
# ----------------------------------------------------------------------------------------------------
#         category            city                company_name geo job_board  \
# 0  catering jobs       Chudleigh             Haulfryn Group   uk      reed
# ...

# %%
print(df['category'].value_counts())
# Adequate number of items to use
# Out:
# health jobs                           1930
# education jobs                        1898
# it jobs                               1890
# logistics jobs                        1885
# construction property jobs            1859
# engineering jobs                      1858
# accountancy jobs                      1856
# sales jobs                            1855
# accountancy qualified jobs            1836
# social care jobs                      1823
# admin secretarial pa jobs             1799
# finance jobs                          1793
# factory jobs                          1755
# recruitment consultancy jobs          1747
# motoring automotive jobs              1578
# retail jobs                           1559
# customer service jobs                 1548
# catering jobs                         1536
# law jobs                              1535
# marketing jobs                        1463
# other jobs                            1452
# hr jobs                               1366
# ...

# %%
print(df['city'].value_counts())
# Adequate number of items to use
# Out:
# London                          4349
# Manchester                      1283
# Central London                   997
# City of London                   943
# Birmingham                       931
# Bristol                          881
# Leeds                            877
# City Of London                   687
# West London                      636
# South West London                493
# Reading                          483
# Glasgow                          478
# East London                      455
# Milton Keynes                    445
# Cambridge                        422
# Edinburgh                        416
# Sheffield                        410
# Liverpool                        399
# South East London                377
# Coventry                         336
# Nottingham                       334
# Leicester                        327
# Southampton                      313
# Swindon                          296
# Newcastle Upon Tyne              292
# ...

# %%
print(df['post_date'].value_counts())
# Numerical values here. Take advantage
# Out:
# 3/7/2018      8472
# 3/12/2018     7503
# 2/27/2018     7090
# 3/8/2018      6464
# 2/28/2018     4081
# 3/6/2018      3085
# 3/9/2018      2215
# 2/26/2018     2098
# 3/2/2018      2024
# 3/5/2018      1203
# 3/1/2018       900
# 2/23/2018      745
# 3/11/2018      616
# 2/22/2018      521
# 3/3/2018       405
# 3/4/2018       392
# 3/10/2018      270
# 2/19/2018      245
# 2/20/2018      196
# 2/21/2018      193
# 2/15/2018      154
# 2/7/2018       132
# 2/16/2018      132
# 2/14/2018       93
# 2/9/2018        72
# 2/1/2018        62
# 2/8/2018        58
# 2/2/2018        54
# 1/31/2018       54
# 1/30/2018       52
#               ...
# 2/5/2018        32
# 1/29/2018       17
# 2/18/2018       16
# 1/3/2018        15
# 2/17/2018       15
# 2/3/2018         7
# 2/10/2018        6
# 1/5/2018         3
# 2/11/2018        3
# 1/26/2018        2
# 1/16/2018        2
# 1/4/2018         2
# 1/17/2018        2
# 1/24/2018        2
# 1/19/2018        2
# 1/9/2018         2
# ...

# %%
print(df['job_title'].value_counts())
# Too much variance
# Out:
# Administrator                                                                 162
# Customer Service Advisor                                                      145
# Management Accountant                                                         139
# Warehouse Operative                                                           131
# Recruitment Consultant                                                        120
# Buyer                                                                         111
# Account Manager                                                               111
# Care Assistant                                                                111
# Vehicle Technician                                                            108
# Support Worker                                                                107
# Sales Executive                                                               102
# ...

# %% [markdown]
# ## Modules
# - posted -> category: See if there is a distribution respect with time
# - city -> distribution: Check a 3d map how jobs are distributed
# - Category distribution: Pie chart to show category distribution
# - Job searcher: Small searcher using scikit-learn
#
# #### Extra
# - Add latitude and longitude to database. Eliminate some columns not used. Create a new csv file (Lower weight).
# - Transform post_date type
